# %% [markdown]
# ## Credit Card Fraud Analysis

# %% [markdown]
# <img src="./Screenshot 2026-03-09 114806.png">

# %% [markdown]
# “This Power BI dashboard analyzes credit card transactions to identify fraudulent activities by displaying transaction distribution, key fraud statistics, detailed transaction data, and interactive filters.”
