# %% [markdown]
# # Assignment 4

# %% [markdown]
# #### Que:1 Write an SQL query to display the names and salaries of employees whose salary is greater than the average salary in the company. Explain how the subquery works?

# %% [markdown]
#  *Answer:*
#
#  How the Subquery Works:
#
#  *Query: SELECT AVG(salary) FROM employees;*
#
#  This Subquery Calculates the average salary from employees table and return in single value.
#   AVG() is the aggregate function to calculate the average of the numeric data column.

# %% [markdown]
# ![Screenshot 2026-02-24 103520.png](<attachment:Screenshot 2026-02-24 103520.png>)

# %% [markdown]
# #### Que:2 Write a query to retrieve the top 5 highest-paid employees from an employees table. Explain how sorting affects the output.

# %% [markdown]
# *Answer:*
#
# How Sorting affects the output:
#
# Sorting is used to arrange values either in ascending or descending order.
#                In this query, the ORDER BY clause is used to sort the salary in descending order by specifying DESC.
#
# After sorting, the employees with the highest salaries appear at the top of the result set.
#                Then, the LIMIT clause is used to return only the required number of records.
#                In this case, it returns the top 5 highest-paid employees.

# %% [markdown]
# ![Screenshot 2026-02-24 104644.png](<attachment:Screenshot 2026-02-24 104644.png>)

# %% [markdown]
# #### Que:3 Write a query to calculate:
# • Total number of employees
#
# • Average salary
#
# • Minimum and maximum salary
#
# Explain the difference between aggregate and scalar functions.

# %% [markdown]
#  *Answer:*
#
#  Aggregate Vs Scalar function :
#
# An aggregate function operates on multiple rows at the same time and returns a single result. A scalar function operates on one row at a time and returns one result for each row.
#
# Generally, aggregate functions are used on numeric values (for example, SUM(), AVG(), COUNT()), while scalar functions are commonly used on character data such as VARCHAR to perform operations like UPPER().

# %% [markdown]
# ![Screenshot 2026-02-24 104753.png](<attachment:Screenshot 2026-02-24 104753.png>)

# %% [markdown]
# #### Que:4 Given a sales table with columns (region, amount), write a query to find total sales per region. Filter only those regions where total sales exceed 50,000.

# %% [markdown]
# *Answer:*
# .

# %% [markdown]
# ![Screenshot 2026-02-24 105628.png](<attachment:Screenshot 2026-02-24 105628.png>)

# %% [markdown]
# #### Que:5 Write a query to find the number of unique job roles in an employees table.Explain why DISTINCT is necessary here.

# %% [markdown]
# *Answer:*
#
# Why DISTINCT is necessary here:
#
# DISTINCT clause is used to get unique values of categorical column.
# Here, we want to find unique job roles in employee table

# %% [markdown]
# ![Screenshot 2026-02-24 105814.png](<attachment:Screenshot 2026-02-24 105814.png>)

# %% [markdown]
# #### Que:6 Write a query to retrieve students who scored between 60 and 80 marks. Rewrite the same query using BETWEEN.

# %% [markdown]
# *Answer:*

# %% [markdown]
# ![Screenshot 2026-02-24 110436.png](<attachment:Screenshot 2026-02-24 110436.png>)

# %% [markdown]
# #### Que:7 Write a query to display employees whose commission is NULL. Explain the correct way to check NULL values in SQL.

# %% [markdown]
# *Answer:*
#
# NULL are not the values, these are missing/ undefined values.
#
# IS NULL checks the NULL values are present or not in the table

# %% [markdown]
# ![Screenshot 2026-02-24 110635.png](<attachment:Screenshot 2026-02-24 110635.png>)

# %% [markdown]
# #### Que:8 Write a query to increase the salary of employees in the “IT” department by 10%. Explain how arithmetic operations are handled in SQL.

# %% [markdown]
# *Answer:*
#
# Airthmetic Operators Works same in SQL as they in simple Maths.
# | Operator | Meaning            |
# | -------- | ------------------ |
# | +        | Addition           |
# | -        | Subtraction        |
# | *        | Multiplication     |
# | /        | Division           |
# | %        | Modulo / remainder |

# %% [markdown]
# ![Screenshot 2026-02-24 110756.png](<attachment:Screenshot 2026-02-24 110756.png>)

# %% [markdown]
# #### Que:9 Write a query to delete records of students who scored less than 40 marks. What precaution should be taken before executing DELETE?

# %% [markdown]
# *Answer:*
#
# Precautions Before DELETE:
# 1. Always use a WHERE clause
#    - if where miss the whole table is delete.
# 2. Backup / Check Data First
#    - check before the row you want to delete.
# 3. Transaction (Optional)
#    - if database support, then give delete in transaction.
# 4. Test on small / sample table first
#    - use the whole process in temporary table first.

# %% [markdown]
# ![Screenshot 2026-02-24 110840.png](<attachment:Screenshot 2026-02-24 110840.png>)

# %% [markdown]
# #### Que:10 .Write a query to find employees who earn more than the average salary of their department (without using joins). Explain the logic of the subquery

# %% [markdown]
# *Answer:*
#
# The inner query finds the average salary of the employee’s department.
#
# The outer query checks:
#
# If an employee’s salary is greater than that average.
#
# If yes → that employee is shown.

# %% [markdown]
# ![Screenshot 2026-02-24 111409.png](<attachment:Screenshot 2026-02-24 111409.png>)
